# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\HP1\\OneDrive\\Desktop\\New folder (2)\\VictimInfoDetails (1).csv")

# %%
df.head(20)
# Out:
#    District_Name    UnitName      FIRNo  Year  Month   VictimName  age  \
# 0       Bagalkot  Amengad PS  0001/2016  2016      1  MAHxxxxxATH   14
# 1       Bagalkot  Amengad PS  0004/2016  2016      1  KRIxxxxxKAR   49
# 2       Bagalkot  Amengad PS  0004/2016  2016      1  VINxxxxxKAR    0
# 3       Bagalkot  Amengad PS  0004/2016  2016      1  RAGxxxxxKAR   34
# 4       Bagalkot  Amengad PS  0004/2016  2016      1  SANxxxxxNNU   36
# 5       Bagalkot  Amengad PS  0005/2016  2016      1  BASxxxxxHMI   60
# 6       Bagalkot  Amengad PS  0006/2016  2016      1  IRSxxxxxWAR   40
# 7       Bagalkot  Amengad PS  0011/2016  2016      1  GANxxxxxRAD   20
# 8       Bagalkot  Amengad PS  0011/2016  2016      1  BASxxxxxAMI   18
# 9       Bagalkot  Amengad PS  0012/2016  2016      1  MOTxxxxxJAN   55
# 10      Bagalkot  Amengad PS  0015/2016  2016      1  SUMxxxxxNDI   35
# 11      Bagalkot  Amengad PS  0021/2016  2016      2  VEExxxxxATH   47
# 12      Bagalkot  Amengad PS  0024/2016  2016      2  MANxxxxxERI   22
# 13      Bagalkot  Amengad PS  0040/2016  2016      2  SHAxxxxxADI   45
# 14      Bagalkot  Amengad PS  0040/2016  2016      2  MALxxxxxNDI   73
# 15      Bagalkot  Amengad PS  0041/2016  2016      2  SHAxxxxxLAD   34
# 16      Bagalkot  Amengad PS  0042/2016  2016      2  SUMxxxxxALI   35
# 17      Bagalkot  Amengad PS  0042/2016  2016      2  BASxxxxxALI   40
# 18      Bagalkot  Amengad PS  0043/2016  2016      2  MANxxxxxATI   11
# 19      Bagalkot  Amengad PS  0044/2016  2016      2  HANxxxxxDAR   55
#
#         Caste  Profession     Sex  ...  PermanentCity PermanentState  \
# 0   Lingayath         NaN  FEMALE  ...       Bagalkot      Karnataka
# 1         NaN         NaN    MALE  ...       Bagalkot      Karnataka
# 2         NaN         NaN    MALE  ...       Bagalkot      Karnataka
# 3         NaN         NaN    MALE  ...  Belagavi Dist      Karnataka
# 4         NaN         NaN    MALE  ...  Belagavi Dist      Karnataka
# 5      GANIGA  Housewife   FEMALE  ...       Bagalkot      Karnataka
# 6      MUSLIM      Driver    MALE  ...       Bagalkot      Karnataka
# 7   Lingayath   Labourer     MALE  ...       Bagalkot      Karnataka
# 8   Lingayath     Farmer     MALE  ...       Bagalkot      Karnataka
# 9         NaN         NaN    MALE  ...       Bagalkot      Karnataka
# 10  Lingayath         NaN  FEMALE  ...       Bagalkot      Karnataka
# 11  Lingayath         NaN    MALE  ...       Bagalkot      Karnataka
# 12        NaN         NaN  FEMALE  ...       Bagalkot      Karnataka
# 13      KURAB         NaN  FEMALE  ...       Bagalkot      Karnataka
# 14      KURAB         NaN    MALE  ...       Bagalkot      Karnataka
# 15  Lingayath     Farmer     MALE  ...       Bagalkot      Karnataka
# 16  Lingayath  Housewife   FEMALE  ...       Bagalkot      Karnataka
# 17  Lingayath     Farmer     MALE  ...       Bagalkot      Karnataka
# 18      KURAB    Student   FEMALE  ...       Bagalkot      Karnataka
# 19        NaN         NaN    MALE  ...       Bagalkot      Karnataka
#
#    Nationality_Name  DOB    PersonType InjuryType Injury_Nature  \
# 0             India  NaN      Deceased      Fatal           NaN
# 1             India  NaN       Injured      Fatal           NaN
# 2             India  NaN       Injured      Fatal           NaN
# 3             India  NaN       Injured      Fatal           NaN
# 4             India  NaN       Injured      Fatal           NaN
# 5             India  NaN      Deceased      Fatal           NaN
# 6             India  NaN       Injured      Fatal           NaN
# 7             India  NaN       Injured      Fatal           NaN
# 8             India  NaN       Injured      Fatal           NaN
# 9             India  NaN      Deceased      Fatal           NaN
# 10            India  NaN  complainnant      Fatal           NaN
# 11            India  NaN       Injured      Fatal           NaN
# 12            India  NaN      Deceased      Fatal           NaN
# 13            India  NaN       Injured   Grievous           NaN
# 14            India  NaN      Deceased      Fatal           NaN
# 15            India  NaN      Deceased      Fatal           NaN
# 16            India  NaN       Injured      Fatal           NaN
# 17            India  NaN       Injured      Fatal           NaN
# 18            India  NaN        Others      Fatal           NaN
# 19            India  NaN       Injured      Fatal           NaN
#
#              Crime_No      Arr_ID   Victim_ID
# 0   10470124520160001  2016000004  2016000002
# 1   10470124520160004  2016000016  2016000006
# 2   10470124520160004  2016000015  2016000005
# 3   10470124520160004  2016000013  2016000003
# 4   10470124520160004  2016000014  2016000004
# 5   10470124520160005  2016000019  2016000007
# 6   10470124520160006  2016000021  2016000008
# 7   10470124520160011  2016000044  2016000010
# 8   10470124520160011  2016000043  2016000009
# 9   10470124520160012  2016000053  2016000011
# 10  10470124520160015  2016000069  2016000012
# 11  10470124520160021  2016000088  2016000014
# 12  10470124520160024  2016000100  2016000015
# 13  10470124520160040  2016000234  2016000016
# 14  10470124520160040  2016000235  2016000017
# 15  10470124520160041  2016000238  2016000018
# 16  10470124520160042  2016000242  2016000020
# 17  10470124520160042  2016000243  2016000021
# 18  10470124520160043  2016000245  2016000022
# 19  10470124520160044  2016000248  2016000024
#
# [20 rows x 24 columns]

# %%
df.shape
# Out:
# (1465783, 24)

# %%
print(df.columns)
# Out:
# Index(['District_Name', 'UnitName', 'FIRNo', 'Year', 'Month', 'VictimName',
#        'age', 'Caste', 'Profession', 'Sex', 'PresentAddress', 'PresentCity',
#        'PresentState', 'PermanentAddress', 'PermanentCity', 'PermanentState',
#        'Nationality_Name', 'DOB', 'PersonType', 'InjuryType', 'Injury_Nature',
#        'Crime_No', 'Arr_ID', 'Victim_ID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465783 entries, 0 to 1465782
# Data columns (total 19 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   District_Name     1465783 non-null  object
#  1   UnitName          1465783 non-null  object
#  2   Year              1465783 non-null  int64
#  3   Month             1465783 non-null  int64
#  4   age               1465783 non-null  int64
#  5   Caste             1277136 non-null  object
#  6   Profession        1285055 non-null  object
#  7   Sex               1465556 non-null  object
#  8   PresentAddress    1465783 non-null  object
#  9   PresentCity       1465678 non-null  object
#  10  PresentState      1464835 non-null  object
#  11  PermanentAddress  1465783 non-null  object
#  12  PermanentCity     1465678 non-null  object
#  13  PermanentState    1464835 non-null  object
#  14  Nationality_Name  1465779 non-null  object
#  15  PersonType        1465783 non-null  object
#  16  InjuryType        1009647 non-null  object
#  17  Crime_No          1465783 non-null  int64
#  18  Arr_ID            1465783 non-null  int64
# dtypes: int64(5), object(14)
# memory usage: 212.5+ MB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         District_Name          UnitName  Year  Month  age  \
# 0            Bagalkot        Amengad PS  2016      1   14
# 1            Bagalkot        Amengad PS  2016      1   49
# 2            Bagalkot        Amengad PS  2016      1    0
# 3            Bagalkot        Amengad PS  2016      1   34
# 4            Bagalkot        Amengad PS  2016      1   36
# ...               ...               ...   ...    ...  ...
# 1465778        Yadgir  Yadgiri Women PS  2024      1   19
# 1465779        Yadgir  Yadgiri Women PS  2024      1   16
# 1465780        Yadgir  Yadgiri Women PS  2024      2   29
# 1465781        Yadgir  Yadgiri Women PS  2024      2   29
# 1465782        Yadgir  Yadgiri Women PS  2024      2   17
#
#                          Caste           Profession     Sex  \
# 0                    Lingayath                  NaN  FEMALE
# 1                          NaN                  NaN    MALE
# 2                          NaN                  NaN    MALE
# 3                          NaN                  NaN    MALE
# 4                          NaN                  NaN    MALE
# ...                        ...                  ...     ...
# 1465778              CHRISTIAN             Student   FEMALE
# 1465779  HOLAYA, HOLER, HOLEYA  House help - hired   FEMALE
# 1465780              Lingayath             Teacher   FEMALE
# 1465781                  REDDY  House help - hired   FEMALE
# 1465782              KABBALIGA             Student   FEMALE
#
#                                             PresentAddress    PresentCity  \
# 0                                  HUVINAHALLI,TQ-HUANGUND       Bagalkot
# 1             BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,GOKAK       Bagalkot
# 2             BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,GOKAK       Bagalkot
# 3          BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,TQ-GOKAK  Belagavi Dist
# 4          BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,TQ-GOKAK  Belagavi Dist
# ...                                                    ...            ...
# 1465778      R/o Hosalli Cross Near Ratnama School,yadgiri         Yadgir
# 1465779                   R/o Talak Village,tq dist yadgir         Yadgir
# 1465780       R/o Bilahar Village,Tq wadagera dist Yadgiri         Yadgir
# 1465781  R/o Thanagundi Village,Now at Mini Vidanasouda...         Yadgir
# 1465782                        R/o Bandalli,TQ DIST YADGIR         Yadgir
#
#         PresentState PermanentAddress  PermanentCity PermanentState  \
# 0          Karnataka                ,       Bagalkot      Karnataka
# 1          Karnataka                ,       Bagalkot      Karnataka
# 2          Karnataka                ,       Bagalkot      Karnataka
# 3          Karnataka                ,  Belagavi Dist      Karnataka
# 4          Karnataka                ,  Belagavi Dist      Karnataka
# ...              ...              ...            ...            ...
# 1465778    Karnataka                ,         Yadgir      Karnataka
# 1465779    Karnataka                ,         Yadgir      Karnataka
# 1465780    Karnataka                ,         Yadgir      Karnataka
# 1465781    Karnataka                ,         Yadgir      Karnataka
# 1465782    Karnataka                ,         Yadgir      Karnataka
#
#         Nationality_Name    PersonType InjuryType           Crime_No  \
# 0                  India      Deceased      Fatal  10470124520160001
# 1                  India       Injured      Fatal  10470124520160004
# 2                  India       Injured      Fatal  10470124520160004
# 3                  India       Injured      Fatal  10470124520160004
# 4                  India       Injured      Fatal  10470124520160004
# ...                  ...           ...        ...                ...
# 1465778            India       Missing        NaN  10978218320240002
# 1465779            India     Kidnapped        NaN  10978218320240003
# 1465780            India  complainnant     Abused  10978218320240004
# 1465781            India  complainnant     Abused  10978218320240005
# 1465782            India     Kidnapped        NaN  10978218320240006
#
#              Arr_ID
# 0        2016000004
# 1        2016000016
# 2        2016000015
# 3        2016000013
# 4        2016000014
# ...             ...
# 1465778  2024000004
# 1465779  2024000007
# 1465780  2024000009
# 1465781  2024000012
# 1465782  2024000017
#
# [1465783 rows x 19 columns]>

# %% [markdown]
# FIRNo - Specific case identifier, not relevant for aggregate analysis.
# VictimName - Personally identifiable information, not necessary for aggregate analysis.
# DOB - Redundant if age is already provided.
# Injury_Nature - Sparse data, may not add significant value.
# Victim_ID - Specific case identifier, not relevant for aggregate analysis.

# %%
# Assuming df is your DataFrame
print(df.columns)

# Columns to drop
columns_to_drop = ['FIRNo', 'VictimName', 'DOB', 'Injury_Nature', 'Victim_ID']

# Check for the existence of columns before dropping
columns_in_df = df.columns
columns_to_drop = [col for col in columns_to_drop if col in columns_in_df]

# Drop the columns if they exist in the DataFrame
df.drop(columns_to_drop, axis=1, inplace=True)

# Verify the columns are dropped
print(df.columns)
# Out:
# Index(['District_Name', 'UnitName', 'Year', 'Month', 'age', 'Caste',
#        'Profession', 'Sex', 'PresentAddress', 'PresentCity', 'PresentState',
#        'PermanentAddress', 'PermanentCity', 'PermanentState',
#        'Nationality_Name', 'PersonType', 'InjuryType', 'Crime_No', 'Arr_ID'],
#       dtype='object')
# Index(['District_Name', 'UnitName', 'Year', 'Month', 'age', 'Caste',
#        'Profession', 'Sex', 'PresentAddress', 'PresentCity', 'PresentState',
#        'PermanentAddress', 'PermanentCity', 'PermanentState',
#        'Nationality_Name', 'PersonType', 'InjuryType', 'Crime_No', 'Arr_ID'],
#       dtype='object')

# %%
df.head()
# Out:
#   District_Name    UnitName  Year  Month  age      Caste Profession     Sex  \
# 0      Bagalkot  Amengad PS  2016      1   14  Lingayath        NaN  FEMALE
# 1      Bagalkot  Amengad PS  2016      1   49        NaN        NaN    MALE
# 2      Bagalkot  Amengad PS  2016      1    0        NaN        NaN    MALE
# 3      Bagalkot  Amengad PS  2016      1   34        NaN        NaN    MALE
# 4      Bagalkot  Amengad PS  2016      1   36        NaN        NaN    MALE
#
#                                     PresentAddress    PresentCity  \
# 0                          HUVINAHALLI,TQ-HUANGUND       Bagalkot
# 1     BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,GOKAK       Bagalkot
# 2     BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,GOKAK       Bagalkot
# 3  BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,TQ-GOKAK  Belagavi Dist
# 4  BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,TQ-GOKAK  Belagavi Dist
#
#   PresentState PermanentAddress  PermanentCity PermanentState  \
# 0    Karnataka                ,       Bagalkot      Karnataka
# 1    Karnataka                ,       Bagalkot      Karnataka
# 2    Karnataka                ,       Bagalkot      Karnataka
# 3    Karnataka                ,  Belagavi Dist      Karnataka
# 4    Karnataka                ,  Belagavi Dist      Karnataka
#
#   Nationality_Name PersonType InjuryType           Crime_No      Arr_ID
# 0            India   Deceased      Fatal  10470124520160001  2016000004
# 1            India    Injured      Fatal  10470124520160004  2016000016
# 2            India    Injured      Fatal  10470124520160004  2016000015
# 3            India    Injured      Fatal  10470124520160004  2016000013
# 4            India    Injured      Fatal  10470124520160004  2016000014

# %% [markdown]
# Data cleaning
#
# Handling Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1465778    False
# 1465779    False
# 1465780    False
# 1465781    False
# 1465782    False
# Length: 1465783, dtype: bool

# %%
df.drop_duplicates(keep='first')
# Out:
#         District_Name          UnitName  Year  Month  age  \
# 0            Bagalkot        Amengad PS  2016      1   14
# 1            Bagalkot        Amengad PS  2016      1   49
# 2            Bagalkot        Amengad PS  2016      1    0
# 3            Bagalkot        Amengad PS  2016      1   34
# 4            Bagalkot        Amengad PS  2016      1   36
# ...               ...               ...   ...    ...  ...
# 1465778        Yadgir  Yadgiri Women PS  2024      1   19
# 1465779        Yadgir  Yadgiri Women PS  2024      1   16
# 1465780        Yadgir  Yadgiri Women PS  2024      2   29
# 1465781        Yadgir  Yadgiri Women PS  2024      2   29
# 1465782        Yadgir  Yadgiri Women PS  2024      2   17
#
#                          Caste           Profession     Sex  \
# 0                    Lingayath                  NaN  FEMALE
# 1                          NaN                  NaN    MALE
# 2                          NaN                  NaN    MALE
# 3                          NaN                  NaN    MALE
# 4                          NaN                  NaN    MALE
# ...                        ...                  ...     ...
# 1465778              CHRISTIAN             Student   FEMALE
# 1465779  HOLAYA, HOLER, HOLEYA  House help - hired   FEMALE
# 1465780              Lingayath             Teacher   FEMALE
# 1465781                  REDDY  House help - hired   FEMALE
# 1465782              KABBALIGA             Student   FEMALE
#
#                                             PresentAddress    PresentCity  \
# 0                                  HUVINAHALLI,TQ-HUANGUND       Bagalkot
# 1             BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,GOKAK       Bagalkot
# 2             BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,GOKAK       Bagalkot
# 3          BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,TQ-GOKAK  Belagavi Dist
# 4          BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,TQ-GOKAK  Belagavi Dist
# ...                                                    ...            ...
# 1465778      R/o Hosalli Cross Near Ratnama School,yadgiri         Yadgir
# 1465779                   R/o Talak Village,tq dist yadgir         Yadgir
# 1465780       R/o Bilahar Village,Tq wadagera dist Yadgiri         Yadgir
# 1465781  R/o Thanagundi Village,Now at Mini Vidanasouda...         Yadgir
# 1465782                        R/o Bandalli,TQ DIST YADGIR         Yadgir
#
#         PresentState PermanentAddress  PermanentCity PermanentState  \
# 0          Karnataka                ,       Bagalkot      Karnataka
# 1          Karnataka                ,       Bagalkot      Karnataka
# 2          Karnataka                ,       Bagalkot      Karnataka
# 3          Karnataka                ,  Belagavi Dist      Karnataka
# 4          Karnataka                ,  Belagavi Dist      Karnataka
# ...              ...              ...            ...            ...
# 1465778    Karnataka                ,         Yadgir      Karnataka
# 1465779    Karnataka                ,         Yadgir      Karnataka
# 1465780    Karnataka                ,         Yadgir      Karnataka
# 1465781    Karnataka                ,         Yadgir      Karnataka
# 1465782    Karnataka                ,         Yadgir      Karnataka
#
#         Nationality_Name    PersonType InjuryType           Crime_No  \
# 0                  India      Deceased      Fatal  10470124520160001
# 1                  India       Injured      Fatal  10470124520160004
# 2                  India       Injured      Fatal  10470124520160004
# 3                  India       Injured      Fatal  10470124520160004
# 4                  India       Injured      Fatal  10470124520160004
# ...                  ...           ...        ...                ...
# 1465778            India       Missing        NaN  10978218320240002
# 1465779            India     Kidnapped        NaN  10978218320240003
# 1465780            India  complainnant     Abused  10978218320240004
# 1465781            India  complainnant     Abused  10978218320240005
# 1465782            India     Kidnapped        NaN  10978218320240006
#
#              Arr_ID
# 0        2016000004
# 1        2016000016
# 2        2016000015
# 3        2016000013
# 4        2016000014
# ...             ...
# 1465778  2024000004
# 1465779  2024000007
# 1465780  2024000009
# 1465781  2024000012
# 1465782  2024000017
#
# [1465782 rows x 19 columns]

# %% [markdown]
# Handling Missing Values

# %%
df.isnull().sum()
# Out:
# District_Name            0
# UnitName                 0
# Year                     0
# Month                    0
# age                      0
# Caste               188647
# Profession          180728
# Sex                    227
# PresentAddress           0
# PresentCity            105
# PresentState           948
# PermanentAddress         0
# PermanentCity          105
# PermanentState         948
# Nationality_Name         4
# PersonType               0
# InjuryType          456136
# Crime_No                 0
# Arr_ID                   0
# dtype: int64

# %%
df['Caste'].nunique()
# Out:
# 989

# %%
df['Caste'] = df['Caste'].fillna('unknown')
df['Caste'].isnull().sum()
# Out:
# 0

# %%
df['Profession'] = df['Profession'].fillna('unknown')
df['Profession'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].nunique()
# Out:
# 3

# %%
df['Sex'].unique()
# Out:
# array(['FEMALE', 'MALE', nan, 'Enuch'], dtype=object)

# %%
df['Sex'] = df['Sex'].fillna('unknown')
df['Sex'].isnull().sum()
# Out:
# 0

# %%
df['PresentCity'] = df['PresentCity'].fillna('unknown')
df['PresentCity'].isnull().sum()
# Out:
# 0

# %%
df['PresentState'] = df['PresentState'].fillna('unknown')
df['PresentState'].isnull().sum()
# Out:
# 0

# %%
df['PermanentCity'] = df['PermanentCity'].fillna('unknown')
df['PermanentCity'].isnull().sum()
# Out:
# 0

# %%
df['PermanentState'] = df['PermanentState'].fillna('unknown')
df['PermanentState'].isnull().sum()
# Out:
# 0

# %%
df['Nationality_Name'] = df['Nationality_Name'].fillna('unknown')
df['Nationality_Name'].isnull().sum()
# Out:
# 0

# %%
df['InjuryType'] = df['InjuryType'].fillna('unknown')
df['InjuryType'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#   District_Name    UnitName  Year  Month  age      Caste Profession     Sex  \
# 0      Bagalkot  Amengad PS  2016      1   14  Lingayath    unknown  FEMALE
# 1      Bagalkot  Amengad PS  2016      1   49    unknown    unknown    MALE
# 2      Bagalkot  Amengad PS  2016      1    0    unknown    unknown    MALE
# 3      Bagalkot  Amengad PS  2016      1   34    unknown    unknown    MALE
# 4      Bagalkot  Amengad PS  2016      1   36    unknown    unknown    MALE
#
#                                     PresentAddress    PresentCity  \
# 0                          HUVINAHALLI,TQ-HUANGUND       Bagalkot
# 1     BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,GOKAK       Bagalkot
# 2     BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,GOKAK       Bagalkot
# 3  BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,TQ-GOKAK  Belagavi Dist
# 4  BASAVA NAGAR GOKAK CTS 190/5 PLAT NO 2,TQ-GOKAK  Belagavi Dist
#
#   PresentState PermanentAddress  PermanentCity PermanentState  \
# 0    Karnataka                ,       Bagalkot      Karnataka
# 1    Karnataka                ,       Bagalkot      Karnataka
# 2    Karnataka                ,       Bagalkot      Karnataka
# 3    Karnataka                ,  Belagavi Dist      Karnataka
# 4    Karnataka                ,  Belagavi Dist      Karnataka
#
#   Nationality_Name PersonType InjuryType           Crime_No      Arr_ID
# 0            India   Deceased      Fatal  10470124520160001  2016000004
# 1            India    Injured      Fatal  10470124520160004  2016000016
# 2            India    Injured      Fatal  10470124520160004  2016000015
# 3            India    Injured      Fatal  10470124520160004  2016000013
# 4            India    Injured      Fatal  10470124520160004  2016000014

# %%
df.PermanentAddress
# Out:
# 0          ,
# 1          ,
# 2          ,
# 3          ,
# 4          ,
#           ..
# 1465778    ,
# 1465779    ,
# 1465780    ,
# 1465781    ,
# 1465782    ,
# Name: PermanentAddress, Length: 1465783, dtype: object

# %% [markdown]
# Analysis of District name

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(18, 10))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=df['District_Name'], palette="Pastel2", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="Districts")

# Add title and labels
plt.title('District-wise Count Plot', fontsize=16)
plt.xlabel('District Name', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Display the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
 District Banglore city counts the highest number of victims.

# %% [markdown]
# Analysing UnitName

# %%
# Filter the dataframe to include only units with counts above a certain threshold, if necessary
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['UnitName'].map(df['UnitName'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['UnitName'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="Units")

# Add title and labels
plt.title('Unit-wise Count Plot', fontsize=20)
plt.xlabel('Unit Name', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('Count', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Analysing Year

# %%
# Filter the dataframe to include only units with counts above a certain threshold, if necessary
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['Year'].map(df['Year'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['Year'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="years")

# Add title and labels
plt.title('YearCount Plot', fontsize=20)
plt.xlabel('year Name', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('Count', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# The plot shows an increasing trend in victim counts from 2016 to 2023, with a significant drop in 2024.

# %%
Analysing Month

# %%
# Filter the dataframe to include only units with counts above a certain threshold, if necessary
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['Month'].map(df['Month'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['Month'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="Months")

# Add title and labels
plt.title('Monthwise Count Plot', fontsize=20)
plt.xlabel('Month Name', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('Count', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Victim counts are relatively consistent across months, with a slight dip in April and peaks in January and December.

# %% [markdown]
# Analysing Age

# %%
# Filter the dataframe to include only units with counts above a certain threshold, if necessary
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['age'].map(df['age'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['age'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="age")

# Add title and labels
plt.title('agewise Count Plot', fontsize=20)
plt.xlabel('age', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('Count', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Victim counts peak at age 30 and 35, with significant counts between ages 20-40 and very young children (age 0).

# %%
Analysing Caste

# %%
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['Caste'].map(df['Caste'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['Caste'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="Caste")

# Add title and labels
plt.title('Caste Plot', fontsize=20)
plt.xlabel('Caste Name', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('Count', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
The highest victim counts are from the Lingayat, Muslim, and SC communities, with significant variability among other castes.

# %%
Analysing Profession

# %%
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['Profession'].map(df['Profession'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['Profession'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="Profession")

# Add title and labels
plt.title('Profession Plot', fontsize=20)
plt.xlabel('Profession Name', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('Count', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# The highest victim count are Farmer,labourer and Housewife

# %% [markdown]
# Analysis of sex

# %%
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['Sex'].map(df['Sex'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['Sex'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="Sex")

# Add title and labels
plt.title('Sex Plot', fontsize=20)
plt.xlabel('Sex Name', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('Count', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# The majority of victims are male, with counts nearly double those of female victims.

# %%
Analysis of Presentcity and permanent city

# %%
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['PresentCity'].map(df['PresentCity'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['PresentCity'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="PresentCity")

# Add title and labels
plt.title('PresentCity Plot', fontsize=20)
plt.xlabel('PresentCity Name', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('Count', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['PermanentCity'].map(df['PermanentCity'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['PermanentCity'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="PermanentCity")

# Add title and labels
plt.title('PermanentCity Plot', fontsize=20)
plt.xlabel('PermanentCity Name', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('Count', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Banglore city counts the highest number of victims in both present and permanent city.

# %%
df.PresentState
# Out:
# 0          Karnataka
# 1          Karnataka
# 2          Karnataka
# 3          Karnataka
# 4          Karnataka
#              ...
# 1465778    Karnataka
# 1465779    Karnataka
# 1465780    Karnataka
# 1465781    Karnataka
# 1465782    Karnataka
# Name: PresentState, Length: 1465783, dtype: object

# %%
df.PersonType
# Out:
# 0              Deceased
# 1               Injured
# 2               Injured
# 3               Injured
# 4               Injured
#                ...
# 1465778         Missing
# 1465779       Kidnapped
# 1465780    complainnant
# 1465781    complainnant
# 1465782       Kidnapped
# Name: PersonType, Length: 1465783, dtype: object

# %%
threshold = 500  # Adjust this threshold based on your data
filtered_df = df[df['PersonType'].map(df['PersonType'].value_counts()) > threshold]

# Create a larger figure to accommodate long x-axis labels and legend
plt.figure(figsize=(24, 12))

# Your current plot code with increased bar width and a specific color palette
sns.countplot(x=filtered_df['PersonType'], palette="Paired", width=0.8)

# Rotate the x labels and adjust the spacing
plt.xticks(rotation=90, ha='center', fontsize=12)

# Increase the space between the x-axis labels and the axis
plt.gca().margins(x=0.02)  # Add a margin to the x-axis

# Move the legend outside of the plot
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title="PersonType")

# Add title and labels
plt.title('PersonType Plot', fontsize=20)
plt.xlabel('PersonType Name', fontsize=16, labelpad=20)  # Increase the padding for the x-axis label
plt.ylabel('PersonType', fontsize=16)

# Display the plot
plt.tight_layout()  # Adjust layout to make room for the labels
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
#  Prediction of Vulnerable Population Areas

# %%
features = df[['District_Name', 'Year', 'Month', 'age', 'Caste', 'Profession', 'Sex', 'PresentCity', 'PresentState', 'PersonType']]
target = df['Crime_No']

# %%
# Encode categorical variables
features_encoded = pd.get_dummies(features, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_encoded, target, test_size=0.3, random_state=42)

# %%
# Verify that lengths are the same
if len(features_encoded) == len(target):
    print("Lengths are consistent.")
else:
    print("Lengths are inconsistent. Check your data cleaning process.")
# Out:
# Lengths are consistent.

# %%
# Check Lengths of Features and Target
print("Length of features_encoded:", len(features_encoded))
print("Length of target:", len(target))
# Out:
# Length of features_encoded: 1465783
# Length of target: 1465783

# %%
# Initialize and train the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[131], line 3
#       1 # Initialize and train the model
#       2 model = RandomForestClassifier(n_estimators=100, random_state=42)
# ----> 3 model.fit(X_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:348, in BaseForest.fit(self, X, y, sample_weight)
#     346 if issparse(y):
#     347     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 348 X, y = self._validate_data(
#     349     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     350 )
#     351 if sample_weight is not None:
#     352     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:621, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     619         y = check_array(y, input_name="y", **check_y_params)
#     620     else:
# --> 621         X, y = check_X_y(X, y, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1147, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1142         estimator_name = _check_estimator_name(estimator)
#    1143     raise ValueError(
#    1144         f"{estimator_name} requires y to be passed, but the target y is None"
#    1145     )
# -> 1147 X = check_array(
#    1148     X,
#    1149     accept_sparse=accept_sparse,
#    1150     accept_large_sparse=accept_large_sparse,
#    1151     dtype=dtype,
#    1152     order=order,
#    1153     copy=copy,
#    1154     force_all_finite=force_all_finite,
#    1155     ensure_2d=ensure_2d,
#    1156     allow_nd=allow_nd,
#    1157     ensure_min_samples=ensure_min_samples,
#    1158     ensure_min_features=ensure_min_features,
#    1159     estimator=estimator,
#    1160     input_name="X",
#    1161 )
#    1163 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1165 check_consistent_length(X, y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:917, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         array = xp.astype(array, dtype, copy=False)
#     916     else:
# --> 917         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     918 except ComplexWarning as complex_warning:
#     919     raise ValueError(
#     920         "Complex data not supported\n{}\n".format(array)
#     921     ) from complex_warning
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py:380, in _asarray_with_order(array, dtype, order, copy, xp)
#     378     array = numpy.array(array, order=order, dtype=dtype)
#     379 else:
# --> 380     array = numpy.asarray(array, order=order, dtype=dtype)
#     382 # At this point array is a NumPy ndarray. We convert it to an array
#     383 # container that is consistent with the input's namespace.
#     384 return xp.asarray(array)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:971, in DataFrame._values(self)
#     969 blocks = mgr.blocks
#     970 if len(blocks) != 1:
# --> 971     return self.values
#     973 arr = blocks[0].values
#     974 if arr.ndim == 1:
#     975     # non-2D ExtensionArray
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11739, in DataFrame.values(self)
#   11666 """
#   11667 Return a Numpy representation of the DataFrame.
#   11668
#    (...)
#   11736        ['monkey', nan, None]], dtype=object)
#   11737 """
#   11738 self._consolidate_inplace()
# > 11739 return self._mgr.as_array()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1770, in BlockManager.as_array(self, dtype, copy, na_value)
#    1768             arr = arr.astype(dtype, copy=False)
#    1769 else:
# -> 1770     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1771     # The underlying data was copied within _interleave
#    1772     copy = False
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1809, in BlockManager._interleave(self, dtype, na_value)
#    1806 elif is_dtype_equal(dtype, str):
#    1807     dtype = np.dtype("object")
# -> 1809 result = np.empty(self.shape, dtype=dtype)
#    1811 itemmask = np.zeros(self.shape[0])
#    1813 if dtype == np.dtype("object") and na_value is lib.no_default:
#    1814     # much more performant than using to_numpy below
#
# MemoryError: Unable to allocate 15.0 GiB for an array with shape (1966, 1026048) and data type int64

# %%
# Make predictions and evaluate the model
y_pred = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
print(classification_report(y_test, y_pred))
